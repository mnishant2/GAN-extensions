# %%
# %load_ext autoreload
# %matplotlib inline

#install TensorFlow 2.0 
# !pip install tensorboardX

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (1.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.17.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (42.0.2)

# %%
# %autoreload 2

from IPython import display

from utils import Logger

import torch
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets

# %%
# !nvidia-smi
# Out:
# Sat Dec 14 13:59:43 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# DATA_FOLDER = './torch_data/VGAN/MNIST'
DATA_FOLDER = './torch_data/VGAN/cifar10'

# %% [markdown]
# ## Load Data

# %%
def mnist_data():
    compose = transforms.Compose(
        [transforms.ToTensor(),
         transforms.Normalize([0.5], [0.5])]
        )
    out_dir = '{}/dataset'.format(DATA_FOLDER)
    return datasets.MNIST(root=out_dir, train=True, transform=compose, download=True)

# %%
# Load data
data = mnist_data()
# Create loader with data, so that we can iterate over it
data_loader = torch.utils.data.DataLoader(data, batch_size=100, shuffle=True)
# Num batches
num_batches = len(data_loader)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c01c906ab8b5> in <module>()
# ----> 1 data = mnist_data()
#       2 # Create loader with data, so that we can iterate over it
#       3 data_loader = torch.utils.data.DataLoader(data, batch_size=100, shuffle=True)
#       4 # Num batches
#       5 num_batches = len(data_loader)
#
# <ipython-input-8-c9f420e62286> in mnist_data()
#       5         )
#       6     out_dir = '{}/dataset'.format(DATA_FOLDER)
# ----> 7     return datasets.cifar(root=out_dir, train=True, transform=compose, download=True)
#
# TypeError: 'module' object is not callable

# %% [markdown]
# ## Networks

# %%
class DiscriminatorNet(torch.nn.Module):
    """
    A three hidden-layer discriminative neural network
    """
    def __init__(self):
        super(DiscriminatorNet, self).__init__()
        n_features = 784
        n_out = 1
        
        self.hidden0 = nn.Sequential( 
            nn.Linear(n_features, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.hidden1 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.hidden2 = nn.Sequential(
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.out = nn.Sequential(
            torch.nn.Linear(256, n_out),
            torch.nn.Sigmoid()
        )

    def forward(self, x):
        x = self.hidden0(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.out(x)
        return x
    
def images_to_vectors(images):
    return images.view(images.size(0), 784)

def vectors_to_images(vectors):
    return vectors.view(vectors.size(0), 1, 28, 28)

# %%
class GeneratorNet(torch.nn.Module):
    """
    A three hidden-layer generative neural network
    """
    def __init__(self):
        super(GeneratorNet, self).__init__()
        n_features = 100
        n_out = 784
        
        self.hidden0 = nn.Sequential(
            nn.Linear(n_features, 256),
            nn.LeakyReLU(0.2)
        )
        self.hidden1 = nn.Sequential(            
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2)
        )
        self.hidden2 = nn.Sequential(
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2)
        )
        
        self.out = nn.Sequential(
            nn.Linear(1024, n_out),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.hidden0(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.out(x)
        return x
    
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): return n.cuda() 
    return n

# %%
discriminator = DiscriminatorNet()
generator = GeneratorNet()
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()

# %% [markdown]
# ## Optimization

# %%
# Optimizers
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002)

# Loss function
loss = nn.BCELoss()

# Number of steps to apply to the discriminator
d_steps = 2  # In Goodfellow et. al 2014 this variable is assigned to 1
# Number of epochs
num_epochs = 100

# %% [markdown]
# ## Training

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

# %% [markdown]
# ### Generate Samples for Testing

# %%
num_test_samples = 16
test_noise = noise(num_test_samples)

# %% [markdown]
# ### Start training

# %%
logger = Logger(model_name='VGAN', data_name='MNIST')

for epoch in range(num_epochs):
    for n_batch, (real_batch,_) in enumerate(data_loader):

        # 1. Train Discriminator
        for i in range(d_steps):
          real_data = Variable(images_to_vectors(real_batch))
          if torch.cuda.is_available(): real_data = real_data.cuda()
          # Generate fake data
          fake_data = generator(noise(real_data.size(0))).detach()
          # Train D
          d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                  real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        # Train G
        g_error = train_generator(g_optimizer, fake_data)
        # Log error
        logger.log(d_error, g_error, epoch, n_batch, num_batches)

        # Display Progress
        if (n_batch) % 100 == 0:
            display.clear_output(True)
            # Display Images
            test_images = vectors_to_images(generator(test_noise)).data.cpu()
            logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
            # Display status Logs
            logger.display_status(
                epoch, num_epochs, n_batch, num_batches,
                d_error, g_error, d_pred_real, d_pred_fake
            )
        # Model Checkpoints
        logger.save_models(generator, discriminator, epoch)
# Out:
# Epoch: [99/100], Batch Num: [500/600]
# Discriminator Loss: 1.0014, Generator Loss: 1.2643
# D(x): 0.6706, D(G(z)): 0.3681

# %%
# !zip -r /content/imgcifar10.zip /content/data/images/VGAN/MNIST
# !zip -r /content/runcifar10.zip /content/runs
from google.colab import files
files.download('/content/imgcifar10.zip')
files.download('/content/runcifar10.zip')
# Out:
#   adding: content/data/images/VGAN/MNIST/ (stored 0%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_99_batch_100.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_55_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_28_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_86_batch_400.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_5_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_55_batch_200.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_72_batch_300.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_45_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_42_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_69_batch_500.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_36_batch_500.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_51_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_67_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_30_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_62_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_40_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_37_batch_500.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_29_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_64_batch_0.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_59_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_14_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_24_batch_0.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_24_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_77_batch_0.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_95_batch_0.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_3_batch_0.png (deflated 6%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_78_batch_500.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_42_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_3_batch_300.png (deflated 6%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_34_batch_100.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_57_batch_0.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_15_batch_100.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_51_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_27_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_7_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_37_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_51_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_8_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_10_batch_100.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_35_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_92_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_75_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_75_batch_400.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_60_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_6_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_31_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_37_batch_100.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_85_batch_100.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_38_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_30_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_62_batch_100.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_76_batch_500.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_69_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_33_batch_400.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_79_batch_300.png (deflated 29%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_82_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_89_batch_0.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_49_batch_200.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_67_batch_300.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_69_batch_300.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_37_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_8_batch_200.png (deflated 36%)
#   adding: content/data/images/VGAN/MNIST/_epoch_9_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_54_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_13_batch_100.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_59_batch_100.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_67_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_44_batch_300.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_78_batch_100.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_75_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_51_batch_400.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/_epoch_8_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_46_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_50_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_8_batch_300.png (deflated 36%)
#   adding: content/data/images/VGAN/MNIST/_epoch_73_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_48_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_35_batch_500.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/_epoch_11_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_68_batch_300.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_84_batch_300.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_93_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_74_batch_500.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_94_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_61_batch_200.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_80_batch_400.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_57_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_92_batch_300.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_62_batch_0.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_76_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_27_batch_100.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_34_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_60_batch_200.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_38_batch_300.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_97_batch_400.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_47_batch_400.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_81_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_30_batch_500.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_77_batch_300.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_43_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_79_batch_100.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_18_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_87_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_98_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_61_batch_500.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_66_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_20_batch_500.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/_epoch_98_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_81_batch_200.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_62_batch_300.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_66_batch_0.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_38_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_76_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_68_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_39_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_58_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_42_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_66_batch_100.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_55_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_65_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_38_batch_500.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_84_batch_100.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_8_batch_0.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_59_batch_0.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_33_batch_300.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_4_batch_300.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_22_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_80_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_68_batch_100.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_52_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_81_batch_300.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_69_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_25_batch_400.png (deflated 36%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_91_batch_200.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_43_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_72_batch_100.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_86_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_57_batch_300.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch
batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_34_batch_500.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/_epoch_70_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_2_batch_0.png (deflated 5%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_83_batch_500.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_44_batch_100.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_12_batch_0.png (deflated 37%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_53_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_61_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_68_batch_100.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_17_batch_500.png (deflated 9%)
#   adding: content/data/images/VGAN/MNIST/_epoch_75_batch_400.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_69_batch_0.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_6_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_21_batch_500.png (deflated 36%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_10_batch_300.png (deflated 36%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_70_batch_300.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_56_batch_500.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_6_batch_100.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_5_batch_0.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_43_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_28_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_29_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_98_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_88_batch_200.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_73_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_63_batch_200.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_43_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_85_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_47_batch_100.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_7_batch_500.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_86_batch_500.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_10_batch_500.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_51_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_3_batch_400.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_70_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_56_batch_300.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_75_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_58_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_47_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_19_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_69_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_94_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_65_batch_500.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/_epoch_44_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_60_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_32_batch_0.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_52_batch_400.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_47_batch_200.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_80_batch_0.png (deflated 31%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_16_batch_500.png (deflated 29%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_93_batch_200.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_86_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_37_batch_200.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_36_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_78_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_58_batch_0.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_54_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_87_batch_200.png (deflated 30%)
#   adding: content/data/images/VGAN/MNIST/_epoch_87_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_5_batch_200.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_88_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_77_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_13_batch_100.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_54_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_32_batch_300.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_67_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_19_batch_300.png (deflated 39%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_31_batch_500.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_2_batch_400.png (deflated 6%)
#   adding: content/data/images/VGAN/MNIST/_epoch_33_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_1_batch_300.png (deflated 22%)
#   adding: content/data/images/VGAN/MNIST/_epoch_62_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_46_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_64_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_54_batch_400.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_90_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_33_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_12_batch_400.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_93_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_96_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_64_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_8_batch_500.png (deflated 36%)
#   adding: content/data/images/VGAN/MNIST/_epoch_94_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_36_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_18_batch_0.png (deflated 40%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_48_batch_200.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_16_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_82_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_10_batch_200.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_1_batch_200.png (deflated 22%)
#   adding: content/data/images/VGAN/MNIST/_epoch_1_batch_500.png (deflated 6%)
#   adding: content/data/images/VGAN/MNIST/_epoch_4_batch_200.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_5_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_64_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_35_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_94_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_55_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_17_batch_300.png (deflated 34%)
#   adding: content/data/images/VGAN/MNIST/_epoch_11_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_97_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_85_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_53_batch_100.png (deflated 33%)
#   adding: content/data/images/VGAN/MNIST/_epoch_31_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_63_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_89_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_98_batch_200.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_43_batch_0.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_38_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_50_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_42_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_19_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_59_batch_500.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_91_batch_400.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_27_batch_100.png (deflated 35%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_98_batch_500.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_31_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_23_batch_100.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_13_batch_300.png (deflated 37%)
#   adding: content/data/images/VGAN/MNIST/_epoch_58_batch_300.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_15_batch_0.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_21_batch_0.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/_epoch_74_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_7_batch_300.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/_epoch_22_batch_0.png (deflated 7%)
#   adding: content/data/images/VGAN/MNIST/_epoch_59_batch_200.png (deflated 8%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_62_batch_400.png (deflated 32%)
#   adding: content/data/images/VGAN/MNIST/hori_epoch_10_batch_400.png (deflated 34%)
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/Dec14_13-59-51_bf1af48314a8VGAN_MNIST/ (stored 0%)
#   adding: content/runs/Dec14_13-59-51_bf1af48314a8VGAN_MNIST/events.out.tfevents.1576331991.bf1af48314a8 (deflated 38%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-5bc498750c6b> in <module>()
#       2 get_ipython().system('zip -r /content/run2steps.zip /content/runs')
#       3 from google.colab import files
# ----> 4 files.download('/content/img2steps.zip')
#       5 files.download('/content/run2steps.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:
